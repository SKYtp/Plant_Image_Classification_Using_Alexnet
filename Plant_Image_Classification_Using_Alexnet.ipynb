# %% [markdown]
# <a href="https://colab.research.google.com/github/SKYtp/Plant_Image_Classification_Using_Alexnet/blob/main/Plant_Image_Classification_Using_Alexnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multiclass Image Classification Using Alexnet Architecture
#
# This code does image classification for 7 fruit categories = ['apple', 'cabbage', 'carrot', 'cucumber', 'eggplant', 'pear', 'zucchini']

# %%
#importing necessary libraries
import os
import cv2
from glob import glob
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Activation,GlobalAveragePooling2D, Dense, BatchNormalization, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD

# %%
#Setting Training dir paths
train_path = '/content/data/'

# %%
#Setting Test dir paths
test_path = '/content/data2/'

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Displaying the image
img = load_img(train_path + "Holy basil/0fc08a283c1c69c2e4f0da1ab316092c.jpg", target_size=(227,227))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
#Printing the shape of the image array
x = img_to_array(img)
print(x.shape)
# Out:
# (227, 227, 3)

# %%
#Getting the count of images for each class
image_count = []
class_names = []
print('{:18s}'.format('class'), end='')
print('Count:')
print('-' * 24)
#Reading the image from each folder from training path
for folder in os.listdir(train_path):
    folder_num = len(os.listdir(os.path.join(train_path,folder)))
    image_count.append(folder_num)
    class_names.append(folder)
    print('{:20s}'.format(folder), end=' ')
    print(folder_num)
print('-' * 24)
print("Number of classes : ",len(class_names))
# Out:
# class             Count:
# ------------------------
# Mint                 62
# Sweet basil          27
# Holy basil           33
# ------------------------
# Number of classes :  3

# %%
#Plotting the count of images for each class
sns.set(rc={'figure.figsize':(5,5)})
sns.barplot(x=class_names, y=image_count)
plt.ylabel('Number of images in each class')
plt.show()

# %%
#Finding number of classes
className = glob(train_path + '/*')
num_classes = len(className)
print(num_classes)
# Out:
# 3

# %% [markdown]
# # Model using Alexnet architecture
#
# This model consist of 5 convolution layers followed by 3 fully connected layers. Ativation function used is relu. The network consists of a kernel or filters with size 11 x 11, 5 x 5, 3 x 3, 3 x 3 and 3 x 3 for its five convolutional layers respectively.

# %%
#Using Alexnet architecture. input is 227, 227,3 image and output is 7 classes of fruits
model = tf.keras.models.Sequential([
    #1st Convolutional Layer
    tf.keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(227,227,3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    #2nd Convolutional Layer
    tf.keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    #3rd Convolutional Layer
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    #4th Convolutional Layer
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    #5th Convolutional Layer
    tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    #Passing it to a Fully Connected layer
    tf.keras.layers.Flatten(),
    # 1st Fully Connected Layer
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),# Add Dropout to prevent overfitting
    # 2nd Fully Connected Layer
    tf.keras.layers.Dense(4096, activation='relu'),
    #tf.keras.layers.BatchNormalization(),
    #tf.keras.layers.Dropout(0.5),
    # 3rd Fully Connected Layer
    tf.keras.layers.Dense(1000, activation='relu'),
    #tf.keras.layers.BatchNormalization(),
    #tf.keras.layers.Dropout(0.5),
    #Output Layer
    tf.keras.layers.Dense(3, activation='softmax'),
    #tf.keras.layers.BatchNormalization()
])

# %%
# plot graph
plot_model(model, to_file='plant_classification.png')

# %% [markdown]
# # Compiling the model

# %%
model.compile(
    optimizer=tf.optimizers.SGD(learning_rate=0.00001),
    loss='categorical_crossentropy',
    metrics=["accuracy"]
)

# %%
#Getting model's summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 55, 55, 96)        34944
#
#  batch_normalization_18 (Ba  (None, 55, 55, 96)        384
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 27, 27, 96)        0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 27, 27, 256)       614656
#
#  batch_normalization_19 (Ba  (None, 27, 27, 256)       1024
#  tchNormalization)
#
#  max_pooling2d_10 (MaxPooli  (None, 13, 13, 256)       0
#  ng2D)
#
#  conv2d_17 (Conv2D)          (None, 13, 13, 384)       885120
#
#  batch_normalization_20 (Ba  (None, 13, 13, 384)       1536
#  tchNormalization)
#
#  max_pooling2d_11 (MaxPooli  (None, 6, 6, 384)         0
#  ng2D)
#
#  conv2d_18 (Conv2D)          (None, 6, 6, 384)         1327488
#
#  batch_normalization_21 (Ba  (None, 6, 6, 384)         1536
#  tchNormalization)
#
#  conv2d_19 (Conv2D)          (None, 6, 6, 256)         884992
#
#  batch_normalization_22 (Ba  (None, 6, 6, 256)         1024
#  tchNormalization)
#
#  flatten_3 (Flatten)         (None, 9216)              0
#
#  dense_12 (Dense)            (None, 4096)              37752832
#
#  batch_normalization_23 (Ba  (None, 4096)              16384
#  tchNormalization)
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_13 (Dense)            (None, 4096)              16781312
#
#  dense_14 (Dense)            (None, 1000)              4097000
#
#  dense_15 (Dense)            (None, 3)                 3003
#
# =================================================================
# Total params: 62403235 (238.05 MB)
# Trainable params: 62392291 (238.01 MB)
# Non-trainable params: 10944 (42.75 KB)
# _________________________________________________________________

# %%
#Specifing epochs & batch size
epochs = 40
batch_size = 3
image_height = 227
image_width = 227

# %% [markdown]
# # Image Augmentation

# %%
#Creating an object of ImageDataGenerator for augmenting training dataset
train_datagen = ImageDataGenerator(rescale= 1./255,
rotation_range=10,
width_shift_range=0.1,
height_shift_range=0.1,
shear_range=0.1,
zoom_range=0.1,
horizontal_flip=True,
fill_mode='nearest')

#Creating an object of ImageDataGenerator for augmenting test dataset
test_datagen = ImageDataGenerator(rescale= 1./255)

# %%
#Generating batches of Augmented data of image size 227, 227 and batch size of 32
train_generator = train_datagen.flow_from_directory(
directory = train_path,
target_size= (image_height, image_width), # resize to this size
batch_size = batch_size,
color_mode= "rgb",
class_mode= "categorical"
)

test_generator = test_datagen.flow_from_directory(
directory = test_path,
target_size=(image_height, image_width),
batch_size = batch_size,
color_mode= "rgb",
class_mode= "categorical")

nb_train_samples = train_generator.samples
nb_test_samples = test_generator.samples
classes = list(train_generator.class_indices.keys())
# Out:
# Found 122 images belonging to 3 classes.
# Found 24 images belonging to 3 classes.

# %% [markdown]
# # Creating callback list

# %%
from keras.callbacks import ReduceLROnPlateau
#Callback to save the best model. Using checkpoint and earlystopping to monitor validation accuracy
callbacks_list = [
    tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy', factor=0.1, patience=10, verbose=1),
    tf.keras.callbacks.ModelCheckpoint(
        filepath='plant_model.h5',
        monitor='val_accuracy', save_best_only=True, verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10,verbose=1)
]

# %% [markdown]
# # Model Fit

# %%
#Fitting the model
#Training
history = model.fit(
        train_generator,
        steps_per_epoch=nb_train_samples // batch_size,
        epochs=epochs,
        callbacks = callbacks_list,
        validation_data=test_generator,
        verbose = 1,
        validation_steps=nb_test_samples // batch_size)
# Out:
# Epoch 1/40
# 40/40 [==============================] - ETA: 0s - loss: 1.3187 - accuracy: 0.3109
# Epoch 1: val_accuracy improved from -inf to 0.41667, saving model to plant_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 40/40 [==============================] - 67s 2s/step - loss: 1.3187 - accuracy: 0.3109 - val_loss: 1.0923 - val_accuracy: 0.4167 - lr: 1.0000e-05
# Epoch 2/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1785 - accuracy: 0.4370
# Epoch 2: val_accuracy did not improve from 0.41667
# 40/40 [==============================] - 63s 2s/step - loss: 1.1785 - accuracy: 0.4370 - val_loss: 1.0862 - val_accuracy: 0.4167 - lr: 1.0000e-05
# Epoch 3/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1965 - accuracy: 0.3950
# Epoch 3: val_accuracy did not improve from 0.41667
# 40/40 [==============================] - 63s 2s/step - loss: 1.1965 - accuracy: 0.3950 - val_loss: 1.0840 - val_accuracy: 0.4167 - lr: 1.0000e-05
# Epoch 4/40
# 40/40 [==============================] - ETA: 0s - loss: 1.0788 - accuracy: 0.4538
# Epoch 4: val_accuracy did not improve from 0.41667
# 40/40 [==============================] - 65s 2s/step - loss: 1.0788 - accuracy: 0.4538 - val_loss: 1.0941 - val_accuracy: 0.4167 - lr: 1.0000e-05
# Epoch 5/40
# 40/40 [==============================] - ETA: 0s - loss: 1.3142 - accuracy: 0.2941
# Epoch 5: val_accuracy did not improve from 0.41667
# 40/40 [==============================] - 72s 2s/step - loss: 1.3142 - accuracy: 0.2941 - val_loss: 1.0880 - val_accuracy: 0.3333 - lr: 1.0000e-05
# Epoch 6/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1561 - accuracy: 0.4034
# Epoch 6: val_accuracy did not improve from 0.41667
# 40/40 [==============================] - 72s 2s/step - loss: 1.1561 - accuracy: 0.4034 - val_loss: 1.1642 - val_accuracy: 0.3750 - lr: 1.0000e-05
# Epoch 7/40
# 40/40 [==============================] - ETA: 0s - loss: 1.0990 - accuracy: 0.4622
# Epoch 7: val_accuracy did not improve from 0.41667
# 40/40 [==============================] - 68s 2s/step - loss: 1.0990 - accuracy: 0.4622 - val_loss: 1.1609 - val_accuracy: 0.3750 - lr: 1.0000e-05
# Epoch 8/40
# 40/40 [==============================] - ETA: 0s - loss: 1.2054 - accuracy: 0.4083
# Epoch 8: val_accuracy did not improve from 0.41667
# 40/40 [==============================] - 70s 2s/step - loss: 1.2054 - accuracy: 0.4083 - val_loss: 1.2743 - val_accuracy: 0.2917 - lr: 1.0000e-05
# Epoch 9/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1082 - accuracy: 0.4454
# Epoch 9: val_accuracy improved from 0.41667 to 0.50000, saving model to plant_model.h5
# 40/40 [==============================] - 76s 2s/step - loss: 1.1082 - accuracy: 0.4454 - val_loss: 1.2141 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 10/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1833 - accuracy: 0.4034
# Epoch 10: val_accuracy did not improve from 0.50000
# 40/40 [==============================] - 67s 2s/step - loss: 1.1833 - accuracy: 0.4034 - val_loss: 1.3414 - val_accuracy: 0.4583 - lr: 1.0000e-05
# Epoch 11/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1825 - accuracy: 0.4538
# Epoch 11: val_accuracy did not improve from 0.50000
# 40/40 [==============================] - 66s 2s/step - loss: 1.1825 - accuracy: 0.4538 - val_loss: 1.0864 - val_accuracy: 0.3333 - lr: 1.0000e-05
# Epoch 12/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1386 - accuracy: 0.4790
# Epoch 12: val_accuracy did not improve from 0.50000
# 40/40 [==============================] - 67s 2s/step - loss: 1.1386 - accuracy: 0.4790 - val_loss: 1.0878 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 13/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1079 - accuracy: 0.4622
# Epoch 13: val_accuracy did not improve from 0.50000
# 40/40 [==============================] - 72s 2s/step - loss: 1.1079 - accuracy: 0.4622 - val_loss: 1.2594 - val_accuracy: 0.3333 - lr: 1.0000e-05
# Epoch 14/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1523 - accuracy: 0.4622
# Epoch 14: val_accuracy did not improve from 0.50000
# 40/40 [==============================] - 71s 2s/step - loss: 1.1523 - accuracy: 0.4622 - val_loss: 1.0671 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 15/40
# 40/40 [==============================] - ETA: 0s - loss: 1.2283 - accuracy: 0.4118
# Epoch 15: val_accuracy did not improve from 0.50000
# 40/40 [==============================] - 69s 2s/step - loss: 1.2283 - accuracy: 0.4118 - val_loss: 1.0820 - val_accuracy: 0.4583 - lr: 1.0000e-05
# Epoch 16/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1514 - accuracy: 0.4622
# Epoch 16: val_accuracy did not improve from 0.50000
# 40/40 [==============================] - 67s 2s/step - loss: 1.1514 - accuracy: 0.4622 - val_loss: 1.1324 - val_accuracy: 0.4167 - lr: 1.0000e-05
# Epoch 17/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1760 - accuracy: 0.4454
# Epoch 17: val_accuracy improved from 0.50000 to 0.62500, saving model to plant_model.h5
# 40/40 [==============================] - 74s 2s/step - loss: 1.1760 - accuracy: 0.4454 - val_loss: 1.0127 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 18/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1363 - accuracy: 0.5210
# Epoch 18: val_accuracy did not improve from 0.62500
# 40/40 [==============================] - 66s 2s/step - loss: 1.1363 - accuracy: 0.5210 - val_loss: 1.1110 - val_accuracy: 0.4167 - lr: 1.0000e-05
# Epoch 19/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1297 - accuracy: 0.4790
# Epoch 19: val_accuracy did not improve from 0.62500
# 40/40 [==============================] - 67s 2s/step - loss: 1.1297 - accuracy: 0.4790 - val_loss: 1.2282 - val_accuracy: 0.4167 - lr: 1.0000e-05
# Epoch 20/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1413 - accuracy: 0.4706
# Epoch 20: val_accuracy did not improve from 0.62500
# 40/40 [==============================] - 67s 2s/step - loss: 1.1413 - accuracy: 0.4706 - val_loss: 1.2456 - val_accuracy: 0.3333 - lr: 1.0000e-05
# Epoch 21/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1709 - accuracy: 0.4370
# Epoch 21: val_accuracy did not improve from 0.62500
# 40/40 [==============================] - 73s 2s/step - loss: 1.1709 - accuracy: 0.4370 - val_loss: 1.2851 - val_accuracy: 0.3750 - lr: 1.0000e-05
# Epoch 22/40
# 40/40 [==============================] - ETA: 0s - loss: 0.9772 - accuracy: 0.5294
# Epoch 22: val_accuracy did not improve from 0.62500
# 40/40 [==============================] - 69s 2s/step - loss: 0.9772 - accuracy: 0.5294 - val_loss: 1.2664 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 23/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1420 - accuracy: 0.4874
# Epoch 23: val_accuracy did not improve from 0.62500
# 40/40 [==============================] - 68s 2s/step - loss: 1.1420 - accuracy: 0.4874 - val_loss: 1.3184 - val_accuracy: 0.4167 - lr: 1.0000e-05
# Epoch 24/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1070 - accuracy: 0.4538
# Epoch 24: val_accuracy did not improve from 0.62500
# 40/40 [==============================] - 70s 2s/step - loss: 1.1070 - accuracy: 0.4538 - val_loss: 1.3911 - val_accuracy: 0.3750 - lr: 1.0000e-05
# Epoch 25/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1978 - accuracy: 0.4202
# Epoch 25: val_accuracy did not improve from 0.62500
# 40/40 [==============================] - 68s 2s/step - loss: 1.1978 - accuracy: 0.4202 - val_loss: 1.3322 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 26/40
# 40/40 [==============================] - ETA: 0s - loss: 1.0780 - accuracy: 0.4790
# Epoch 26: val_accuracy did not improve from 0.62500
# 40/40 [==============================] - 68s 2s/step - loss: 1.0780 - accuracy: 0.4790 - val_loss: 1.4110 - val_accuracy: 0.3750 - lr: 1.0000e-05
# Epoch 27/40
# 40/40 [==============================] - ETA: 0s - loss: 1.1246 - accuracy: 0.5126
# Epoch 27: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 27: val_accuracy did not improve from 0.62500
# 40/40 [==============================] - 69s 2s/step - loss: 1.1246 - accuracy: 0.5126 - val_loss: 1.2846 - val_accuracy: 0.4167 - lr: 1.0000e-05
# Epoch 27: early stopping

# %% [markdown]
# # Accuracy and loss Learning curves

# %%
#plotting the loss function and accuracy for different epochs

plt.figure(1, figsize = (10, 10))
plt.subplot(211)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')

# plotting model loss
plt.subplot(212)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# # Evaluating model

# %%
# model evaluation
score = model.evaluate(test_generator)
print('test loss:', score[0])
print('test accuracy:', score[1])
# Out:
# 8/8 [==============================] - 1s 143ms/step - loss: 1.2846 - accuracy: 0.4167
# test loss: 1.2846136093139648
# test accuracy: 0.4166666567325592

# %% [markdown]
# # Model Saving and Prediction

# %%
# save the whole model
model.save("./plant_model.h5")

# %%
# make a prediction for a new image.

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model

# %%
sample_path='./Dataset/Dataset/new_samples/'
img = load_img("/content/data/Holy basil/292d83f842726152d9934a1f45b7808d.jpg", target_size=(227,227))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
def load_image(filename):
    #load the image
    img = load_img(filename, grayscale=False, color_mode="rgb", target_size=(227, 227, 3))
    #convert to array
    img = img_to_array(img)
    #reshape into a single sample with 1 channel
    img = img.reshape(1, 227, 227, 3)
    #prepare pixel data
    img = img.astype('float32')
    img = img / 255.0
    return img

# %%
img = load_image("/content/pre/Mint/mint-600x600.jpg")
model = load_model('plant_model.h5')

# %%
# predict the class
predict_x=model.predict(img)
result=np.argmax(predict_x,axis=1)
if result[0] == 0:
    print("Holy basil")
elif result[0] == 1:
    print("Mint")
elif result[0] == 2:
    print("Sweet basil")
else:
    print("Not in the list")
# Out:
# 1/1 [==============================] - 0s 270ms/step
# Mint
